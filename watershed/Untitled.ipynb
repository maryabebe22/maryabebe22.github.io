# %% [markdown]
# ### Import Libraries and read CSV

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Carbon Inventory.csv')

# %%
df.head()
# Out:
#                Unnamed: 0           Unnamed: 1     Unnamed: 2  \
# 0             Description             Category       Location
# 1  Restaurant electricity  Building operations  San Francisco
# 2  Restaurant electricity  Building operations         Dayton
# 3  Restaurant natural gas  Building operations  San Francisco
# 4  Restaurant natural gas  Building operations         Dayton
#
#              Unnamed: 3 Unnamed: 4      Emissions Factors  \
# 0                Vendor       Unit                 Source
# 1                  PG&E        kWh             eGRID 2018
# 2  Dayton Power & Light        kWh             eGRID 2018
# 3                  PG&E      mmBtu  EPA Emissions Factors
# 4  Dayton Power & Light      mmBtu  EPA Emissions Factors
#
#               Unnamed: 6               Unnamed: 7  \
# 0                   Name  Amount (kg CO2e / unit)
# 1  CAMX Electricity Grid             0.2394512168
# 2  Ohio Electricity Grid             0.5639962928
# ...

# %%
# renaming columns to clean df
df = df.rename(columns={'Unnamed: 0': 'Description'.strip(),
                        'Unnamed: 1': 'Category'.strip(),
                        'Unnamed: 2': 'Location'.strip(),
                        'Unnamed: 3': 'Vendor'.strip(),
                        'Unnamed: 4': 'Unit'.strip(),
                        'Unnamed: 5': 'Source'.strip(),
                        'Unnamed: 6': 'Name'.strip(),
                        'Unnamed: 7': 'Amount (kg CO2e / unit)'.strip(),
                        'Unnamed: 8': 'Activity Data 2019 total (measured in specified Unit)'.strip(),
                        'Unnamed: 9': 'CO2e (kg)'.strip(),
                       })

# %%
# excluding the first row (header) from the DataFrame
df = df.iloc[1:]

# %%
df.head()
# Out:
#               Description             Category       Location  \
# 1  Restaurant electricity  Building operations  San Francisco
# 2  Restaurant electricity  Building operations         Dayton
# 3  Restaurant natural gas  Building operations  San Francisco
# 4  Restaurant natural gas  Building operations         Dayton
# 5  Waste sent to landfill                Waste  San Francisco
#
#                  Vendor           Unit                Emissions Factors  \
# 1                  PG&E            kWh                       eGRID 2018
# 2  Dayton Power & Light            kWh                       eGRID 2018
# 3                  PG&E          mmBtu            EPA Emissions Factors
# 4  Dayton Power & Light          mmBtu            EPA Emissions Factors
# 5              Recology  tons of waste  UK Government Emissions Factors
#
#                                      Name Amount (kg CO2e / unit)  \
# 1                   CAMX Electricity Grid            0.2394512168
# ...

# %% [markdown]
# ### Data Exploration

# %%
df.describe()
# Out:
#        Description               Category       Location  \
# count           52                     52             52
# unique          16                      5              2
# top           Beef  Ingredient production  San Francisco
# freq             4                     20             26
#
#                             Vendor Unit  Emissions Factors  \
# count                           52   52                 52
# unique                          15    6                  6
# top     California Organic Farmers   kg  Poore and Nemecek
# freq                            11   20                 20
#
#                                                      Name  \
# count                                                  52
# unique                                                 18
# top     transport, freight, lorry with reefer, cooling...
# freq                                                   16
#
#        Amount (kg CO2e / unit)  \
# count                       52
# ...

# %%
df.isna().sum()
# Out:
# Description                                               0
# Category                                                  0
# Location                                                  0
# Vendor                                                    0
# Unit                                                      0
# Emissions Factors                                         0
# Name                                                      0
# Amount (kg CO2e / unit)                                   0
# Activity Data 2019 total (measured in specified Unit)     0
# CO2e (kg)                                                49
# dtype: int64
